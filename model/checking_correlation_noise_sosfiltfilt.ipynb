# %% [markdown]
# ### In this notebook the effects of filtering on the cross correlation are analysed

# %% [markdown]
# #### Importing libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from scipy import signal
from scipy.fft import fft, ifft, ifftshift

# %% [markdown]
# #### Defining paths

# %%
data_path =  r"..\data\avstand_1.npz"
noise_path = r"..\data\avstand_1_noise.npz"

# %% [markdown]
# #### Loading data

# %%
data_noise = np.load(noise_path)['data']
data = np.load(data_path)['data']

# %% [markdown]
# #### Generating Random Noise Data
#
# Assuming that the background noise of the system can be approximated as white gaussian background noise.

# %%
mean = 0
std = 1
num_samples = 204800
w1 = np.random.normal(mean, std, size=num_samples)
w2 = np.random.normal(mean, std, size=num_samples)

# %% [markdown]
# #### Defining the two system noise variables we will analyse in this notebook

# %%
q1 = data_noise[0][:num_samples]
q2 = data_noise[1][:num_samples]

# %% [markdown]
# #### Defining Cross Correlation Parameters

# %%
numtaps = 1001
truncate_length = 60
window_type = signal.windows.boxcar
beta = 1
correlation_type = np.real
frequency_central = 10000 #Hz
band_width = 1000
sampling_rate = 204800 #Hz
window_size = 1000
step_size = 1000
order = 4

# %% [markdown]
# #### Creating Filter

# %%
Wn = [frequency_central - band_width/2, frequency_central + band_width/2]
sos = signal.butter(order, Wn, fs=sampling_rate, btype='bandpass', analog=False, output='sos')

# %% [markdown]
# #### Defining Cross Correlation Functions

# %%
def truncate_time_shift(time_shift,length):
    index_0 = len(time_shift)/2
    start_index = int(index_0 - length/2)
    end_index = int(index_0 + length/2)
    time_shift = time_shift[start_index:end_index]
    return time_shift


def create_gcc(sensor_1, 
               sensor_2, 
               window_size, 
               step_size, 
               truncate_length, 
               window_type, 
               beta,
               correlation_type): 
    '''
    Inputs: 
    sensor_1: sensor 1 data
    sensor_2: sensor 2 data
    window_size: window size in samples
    step_size: step size in samples
    truncate_length: length of truncated output in samples
    window_type: window type. Example: signal.windows.boxcar
    beta: power of denominator
    correlation_type: real, imag or abs

    Outputs:
    GCC: cross correlation 
    '''
    GCC_12 = []
    for i in tqdm(range(0, len(sensor_1) - window_size, step_size)):
        j = i
        k = i + window_size

        s1 = sensor_1[j:k]
        s2 = sensor_2[j:k]

        window = window_type(len(s1))
        s1 = s1 * window
        s2 = s2 * window

        f_s1 = fft(s1)
        f_s2 = fft(s2)

        G12 = f_s1 * np.conj(f_s2)
        denom = abs(G12)
        max_denom = 1e-6
        denom[denom < max_denom] = max_denom

        f_s = G12 / denom**beta


        # Er f_s 1 
        cc12 = ifft(f_s)
        cc12 = ifftshift(cc12)

        cc12 = correlation_type(cc12)

        index_0 = len(cc12)/2
        start_index = int(index_0 - truncate_length/2)
        end_index = int(index_0 + truncate_length/2)
        cc12 = cc12[start_index:end_index]

        cc12 = cc12 / np.max(np.abs(cc12))
        GCC_12.append(cc12)

    GCC_12 = np.array(GCC_12)
    return GCC_12

# %% [markdown]
# #### Creating the time_shifts

# %%
dt = 1 / sampling_rate
time_shifts = np.arange(-window_size*dt,window_size*dt,dt)
time_shifts = truncate_time_shift(time_shifts, truncate_length)
time = np.arange(window_size/2, len(q1) - window_size/2, step_size)/sampling_rate

# %% [markdown]
# #### Plotting the cross correlation of the system signal

# %%
sensor_1 = data[0][:num_samples]
sensor_2 = data[1][:num_samples]

GCC_12 = create_gcc(sensor_1,
                    sensor_2,
                    window_size,
                    step_size,
                    truncate_length,
                    window_type,
                    beta,
                    correlation_type)
# Out:
# 100%|██████████| 204/204 [00:00<00:00, 8215.52it/s]

# %%
fig, ax = plt.subplots(1,1,figsize = (10,5))
ax.pcolormesh(time, time_shifts*1000, GCC_12.T, vmin = -1, vmax = 1)
ax.set_title('GCC_12')
ax.set_xlabel('Time [s ]')
ax.set_ylabel('Time shift [ms]')
ax.set_aspect('auto')

# %% [markdown]
# #### Calculating the cross correlation and auto correlation for the system noise

# %%
GCC_q1q2 = create_gcc(q1,q2, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_q1q1 = create_gcc(q1,q1, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_q2q2 = create_gcc(q2,q2, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_q2q1 = create_gcc(q2,q1, window_size, step_size, truncate_length, window_type, beta, correlation_type)

fig, ax = plt.subplots(2,2 ,figsize = (10,10))

ax = ax.ravel()

ax[1].pcolormesh(time, time_shifts*1000, GCC_q1q2.T, vmin = -1, vmax = 1)
ax[1].set_title('GCC_q1q2')
ax[1].set_xlabel('Time [s]')
ax[1].set_ylabel('Time shift [ms]')
ax[1].set_aspect('auto')

ax[0].pcolormesh(time, time_shifts*1000, GCC_q1q1.T, vmin = -1, vmax = 1)
ax[0].set_title('GCC_q1q1')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('Time shift [ms]')
ax[0].set_aspect('auto')


ax[3].pcolormesh(time, time_shifts*1000, GCC_q2q2.T, vmin = -1, vmax = 1)
ax[3].set_title('GCC_q2q2')
ax[3].set_xlabel('Time [s]')
ax[3].set_ylabel('Time shift [ms]')
ax[3].set_aspect('auto')

ax[2].pcolormesh(time, time_shifts*1000, GCC_q2q1.T, vmin = -1, vmax = 1)
ax[2].set_title('GCC_q2q1')
ax[2].set_xlabel('Time [s]')    
ax[2].set_ylabel('Time shift [ms]')
ax[2].set_aspect('auto')

fig.suptitle('GCC of q1 and q2')
fig.tight_layout()
# Out:
# 100%|██████████| 204/204 [00:00<00:00, 8182.36it/s]
# 100%|██████████| 204/204 [00:00<00:00, 3846.57it/s]
# 100%|██████████| 204/204 [00:00<00:00, 3394.88it/s]
# 100%|██████████| 204/204 [00:00<00:00, 6641.09it/s]

# %% [markdown]
# #### Calculating the cross correlation and auto correlation for the random noise

# %%
GCC_w1w2 = create_gcc(w1,w2, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_w1w1 = create_gcc(w1,w1, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_w2w2 = create_gcc(w2,w2, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_w2w1 = create_gcc(w2,w1, window_size, step_size, truncate_length, window_type, beta, correlation_type)

fig, ax = plt.subplots(2,2 ,figsize = (10,10))

ax = ax.ravel()

ax[1].pcolormesh(time, time_shifts*1000, GCC_w1w2.T, vmin = -1, vmax = 1)
ax[1].set_title('GCC_w1w2')
ax[1].set_xlabel('Time [s]')
ax[1].set_ylabel('Time shift [ms]')
ax[1].set_aspect('auto')

ax[0].pcolormesh(time, time_shifts*1000, GCC_w1w1.T, vmin = -1, vmax = 1)
ax[0].set_title('GCC_w1w1')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('Time shift [ms]')
ax[0].set_aspect('auto')


ax[3].pcolormesh(time, time_shifts*1000, GCC_w2w2.T, vmin = -1, vmax = 1)
ax[3].set_title('GCC_w2w2')
ax[3].set_xlabel('Time [s]')
ax[3].set_ylabel('Time shift [ms]')
ax[3].set_aspect('auto')

ax[2].pcolormesh(time, time_shifts*1000, GCC_w2w1.T, vmin = -1, vmax = 1)
ax[2].set_title('GCC_w2w1')
ax[2].set_xlabel('Time [s]')    
ax[2].set_ylabel('Time shift [ms]')
ax[2].set_aspect('auto')

fig.suptitle('GCC of w1 and w2')
fig.tight_layout()
# Out:
# 100%|██████████| 204/204 [00:00<00:00, 6831.66it/s]
# 100%|██████████| 204/204 [00:00<00:00, 6519.25it/s]
# 100%|██████████| 204/204 [00:00<00:00, 7865.62it/s]
# 100%|██████████| 204/204 [00:00<00:00, 8753.96it/s]

# %% [markdown]
# #### Calculating the cross correlation for the filtered system noise

# %%
q1 = signal.sosfiltfilt(sos, q1)
q2 = signal.sosfiltfilt(sos, q2)


GCC_q1q2 = create_gcc(q1,q2, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_q1q1 = create_gcc(q1,q1, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_q2q2 = create_gcc(q2,q2, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_q2q1 = create_gcc(q2,q1, window_size, step_size, truncate_length, window_type, beta, correlation_type)


fig, ax = plt.subplots(2,2 ,figsize = (10,10))

ax = ax.ravel()

ax[1].pcolormesh(time, time_shifts*1000, GCC_q1q2.T, vmin = -1, vmax = 1)
ax[1].set_title('GCC_q1q2')
ax[1].set_xlabel('Time [s]')
ax[1].set_ylabel('Time shift [ms]')
ax[1].set_aspect('auto')

ax[0].pcolormesh(time, time_shifts*1000, GCC_q1q1.T, vmin = -1, vmax = 1)
ax[0].set_title('GCC_q1q1')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('Time shift [ms]')
ax[0].set_aspect('auto')


ax[3].pcolormesh(time, time_shifts*1000, GCC_q2q2.T, vmin = -1, vmax = 1)
ax[3].set_title('GCC_q2q2')
ax[3].set_xlabel('Time [s]')
ax[3].set_ylabel('Time shift [ms]')
ax[3].set_aspect('auto')

ax[2].pcolormesh(time, time_shifts*1000, GCC_q2q1.T, vmin = -1, vmax = 1)
ax[2].set_title('GCC_q2q1')
ax[2].set_xlabel('Time [s]')    
ax[2].set_ylabel('Time shift [ms]')
ax[2].set_aspect('auto')

fig.suptitle('GCC of filtered q1 and q2')
fig.tight_layout()
# Out:
#   0%|          | 0/204 [00:00<?, ?it/s]
# 100%|██████████| 204/204 [00:00<00:00, 6539.48it/s]
# 100%|██████████| 204/204 [00:00<00:00, 7147.53it/s]
# 100%|██████████| 204/204 [00:00<00:00, 8170.57it/s]
# 100%|██████████| 204/204 [00:00<00:00, 7304.16it/s]

# %% [markdown]
# #### Calculating the cross correlation of the filtered random noise

# %%
w1 = signal.sosfiltfilt(sos, w1)
w2 = signal.sosfiltfilt(sos, w2)

GCC_w1w2 = create_gcc(w1,w2, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_w1w1 = create_gcc(w1,w1, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_w2w2 = create_gcc(w2,w2, window_size, step_size, truncate_length, window_type, beta, correlation_type)
GCC_w2w1 = create_gcc(w2,w1, window_size, step_size, truncate_length, window_type, beta, correlation_type)

fig, ax = plt.subplots(2,2 ,figsize = (10,10))

ax = ax.ravel()

ax[1].pcolormesh(time, time_shifts*1000, GCC_w1w2.T, vmin = -1, vmax = 1)
ax[1].set_title('GCC_w1w2')
ax[1].set_xlabel('Time [s]')
ax[1].set_ylabel('Time shift [ms]')
ax[1].set_aspect('auto')

ax[0].pcolormesh(time, time_shifts*1000, GCC_w1w1.T, vmin = -1, vmax = 1)
ax[0].set_title('GCC_w1w1')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('Time shift [ms]')
ax[0].set_aspect('auto')


ax[3].pcolormesh(time, time_shifts*1000, GCC_w2w2.T, vmin = -1, vmax = 1)
ax[3].set_title('GCC_w2w2')
ax[3].set_xlabel('Time [s]')
ax[3].set_ylabel('Time shift [ms]')
ax[3].set_aspect('auto')

ax[2].pcolormesh(time, time_shifts*1000, GCC_w2w1.T, vmin = -1, vmax = 1)
ax[2].set_title('GCC_w2w1')
ax[2].set_xlabel('Time [s]')    
ax[2].set_ylabel('Time shift [ms]')
ax[2].set_aspect('auto')

fig.suptitle('GCC of filtered w1 and w2')
fig.tight_layout()
# Out:
#   0%|          | 0/204 [00:00<?, ?it/s]
# 100%|██████████| 204/204 [00:00<00:00, 6832.20it/s]
# 100%|██████████| 204/204 [00:00<00:00, 7053.84it/s]
# 100%|██████████| 204/204 [00:00<00:00, 8510.42it/s]
# 100%|██████████| 204/204 [00:00<00:00, 7964.02it/s]
